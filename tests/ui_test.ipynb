# %%
import sys
sys.path.append('..')
from src.ui.appcontroller import AppController

from IPython.display import display

testController = AppController()

display(testController.layout)

# %%
from IPython.display import display
import ipywidgets as widgets

container=widgets.Output(
    layout=widgets.Layout(
        
    )
)
label=widgets.Label(
    layout=widgets.Layout(
        
    ),
    value='mytext to be centered mytext to be centered mytext to be centered mytext to be centered'
)
button=widgets.Button(
    layout=widgets.Layout(
        
    ),
    description='OK'
)

#boxing

buttonBox = widgets.HBox([button])
labelBox = widgets.HBox([label])

outputBox = widgets.VBox([labelBox,buttonBox],layout=widgets.Layout(
    justify_content='center',
    align_items='center',
    min_height='300px',
    min_width='600px'
))

container=outputBox

display(container)
